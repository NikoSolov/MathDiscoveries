# %% [markdown]
# - For Social
# 	- Structuring КоАП
# 	- Маска микрофон и "не вынимая наушники"
# 	- Автоматическая оптимизация использования эскалаторов в метров
# 	- Велосипед со встроенным генератором электричества
# 	- Будильник для общественного транспорта
# 	- Панорамные снимки подземного транспорта
#
# - For Science:
# 	- Объединить теорию узлов с цепью плечей, которое умеет рисовать эти узлы.
# - Art
# 	- На Pygame сделать **изометрическую игру** с осмотром стен внутреннего помещения с помощью поворота камеры. Все стены будут нарисованы как прямоугольники и искажены в программе. Искажение можно изобрести с помощью метода прорисовки каждой линии (Алгоритм Брезенхэма).
# 	- Придумать игру на Python с встроенной музыкой и спрайтами, но с внешними текстами и шрифтами разных языков. Для нового движка подойдет пример GameMaker Studio 2 и RPGMaker. В Pygame можно менять иконку во время игры. Субпиксельная графика.
# 	- Первая вымышленная игра называлась UNDER_CONTROL, суть в которой была связь с игроком и Главного Героя, где будет путешествовать по воспоминаниям прямолинейно связанны с автором игры. Предположительно она была для Апогей БК-01 (Черно-белая)
# 	-
