# %% [markdown]
# $$
# \text{Leg}_{n}(m\cdot n^{a})=a
# $$

# %%
for d in range(2,9):
    S=""
    for i in range(1, 100):
        p = i
        while (p%d==0):
            p//=d
        if (i!=p):
            S+=f"({i}, {p}), "
    print(f"A_{d}=\\left[{S}\\right]")
# Out:
# A_2=\left[(2, 1), (4, 1), (6, 3), (8, 1), (10, 5), (12, 3), (14, 7), (16, 1), (18, 9), (20, 5), (22, 11), (24, 3), (26, 13), (28, 7), (30, 15), (32, 1), (34, 17), (36, 9), (38, 19), (40, 5), (42, 21), (44, 11), (46, 23), (48, 3), (50, 25), (52, 13), (54, 27), (56, 7), (58, 29), (60, 15), (62, 31), (64, 1), (66, 33), (68, 17), (70, 35), (72, 9), (74, 37), (76, 19), (78, 39), (80, 5), (82, 41), (84, 21), (86, 43), (88, 11), (90, 45), (92, 23), (94, 47), (96, 3), (98, 49), \right]
# A_3=\left[(3, 1), (6, 2), (9, 1), (12, 4), (15, 5), (18, 2), (21, 7), (24, 8), (27, 1), (30, 10), (33, 11), (36, 4), (39, 13), (42, 14), (45, 5), (48, 16), (51, 17), (54, 2), (57, 19), (60, 20), (63, 7), (66, 22), (69, 23), (72, 8), (75, 25), (78, 26), (81, 1), (84, 28), (87, 29), (90, 10), (93, 31), (96, 32), (99, 11), \right]
# ...
