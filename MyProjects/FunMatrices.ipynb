# %% [markdown]
# $$
# \begin{pmatrix}
# x_{11} & x_{12} \\
# x_{21} & x_{22}
# \end{pmatrix}^{-1}=
# \frac{1}{(x_{11}x_{22}-x_{12}x_{21})}
# \begin{pmatrix}
# x_{22} & -x_{12} \\
# -x_{21} & x_{11}
# \end{pmatrix}
# $$
#
# $$
# \begin{pmatrix}
# x_{11} & 0 \\
# 0 & x_{22}
# \end{pmatrix}^{-1}=
# \frac{1}{(x_{11}x_{22})}
# \begin{pmatrix}
# x_{22} & 0 \\
# 0 & x_{11}
# \end{pmatrix}^{T}=
# \begin{pmatrix}
# \frac{1}{x_{11}} & 0 \\
# 0 & \frac{1}{x_{22}}
# \end{pmatrix}
# $$
#
# $$
# \begin{pmatrix}
# x_{11} & 0 & 0 \\
# 0 & x_{22} & 0 \\
# 0 & 0 & x_{33}
# \end{pmatrix}^{-1}=
# \frac{1}{(x_{11}x_{22}x_{33})}
# \begin{pmatrix}
# x_{22}x_{33} & 0 & 0 \\
# 0 & x_{11}x_{33} & 0 \\
# 0 & 0 & x_{11}x_{22}
# \end{pmatrix}=
# \begin{pmatrix}
# \frac{1}{x_{11}} & 0 & 0 \\
# 0 & \frac{1}{x_{22}} & 0 \\
# 0 & 0 & \frac{1}{x_{33}}
# \end{pmatrix}
# $$
#
# $$
# \begin{pmatrix}
# x_{11} & x_{12} & x_{13} \\
# 0 & x_{22} & x_{23} \\
# 0 & 0 & x_{33}
# \end{pmatrix}^{-1}=
# \begin{pmatrix}
# \frac{1}{x_{11}} & \frac{x_{12}}{x_{11}\cdot x_{22}} & \frac{x_{12}\cdot x_{23}}{x_{11}\cdot x_{22}\cdot x_{33}}-\frac{x_{13}}{x_{11}\cdot x_{22}\cdot x_{33}} \\
# 0 & \frac{1}{x_{22}} & \frac{x_{23}}{x_{22}\cdot x_{33}} \\
# 0 & 0 & \frac{1}{x_{33}}
# \end{pmatrix}
# $$

# %% [markdown]
# $$
# \begin{pmatrix}
# a & d & f\\
# d & b & e\\
# f & e & c
# \end{pmatrix}
# $$
# $$
# \begin{vmatrix}
# a & d & f\\
# d & b & e\\
# f & e & c
# \end{vmatrix}=
# abc+2def-bf^{2}-ae^{2}-cd^{2}
# $$
# $$
# \begin{pmatrix} a & d & f\\  d & b & e\\  f & e & c \end{pmatrix}\to
# \begin{pmatrix}
# \begin{vmatrix}b & e \\ e  & c\end{vmatrix} &
# -\begin{vmatrix}d & e \\ f  & c\end{vmatrix} &
# \begin{vmatrix}d & b \\ f  & e\end{vmatrix} \\
# -\begin{vmatrix}d & f \\ e  & c\end{vmatrix} &
# \begin{vmatrix}a & f \\ f  & c\end{vmatrix} &
# -\begin{vmatrix}a & d \\ f  & e\end{vmatrix} \\
# \begin{vmatrix}d & f \\ b  & e\end{vmatrix} &
# -\begin{vmatrix}a & f \\ d  & e\end{vmatrix} &
# \begin{vmatrix}a & d \\ d  & b\end{vmatrix} \\
# \end{pmatrix}=
# \begin{pmatrix}
# bc-e^{2} & ef-dc & de-bf \\
# ef-dc & ac-f^{2} & df-ae \\
# de-bf & df-ae & ab-d^{2} \\
# \end{pmatrix}
# $$
# $$
# \tilde A=
# \begin{pmatrix}
# bc-e^{2} & ef-dc & de-bf \\
# ef-dc & ac-f^{2} & df-ae \\
# de-bf & df-ae & ab-d^{2} \\
# \end{pmatrix}
# $$
# $$\Large
# \begin{array}{l}
# A^{-1}=\dfrac{1}{\det{A}}\cdot\tilde A=\\
# \dfrac{1}{abc+2def-bf^{2}-ae^{2}-cd^{2}}\cdot
# \begin{pmatrix}
# bc-e^{2} & ef-dc & de-bf \\
# ef-dc & ac-f^{2} & df-ae \\
# de-bf & df-ae & ab-d^{2} \\
# \end{pmatrix}
# \end{array}
# $$
